# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswin-Cheerngodan/CIFAR-10/blob/main/CIFAR_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Conv2D,MaxPooling2D
from tensorflow.keras.layers import Dropout,Flatten,BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping
from keras.models import load_model

# %%
(X_train,y_train),(X_test,y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step

# %%
class_names = ['airplane','automobile','bird',
               'cat','deer','dog','frog','horse','ship','truck']

# %%
plt.figure(figsize=(15,15))

for i in range(64):
  plt.subplot(8,8,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)

  plt.imshow(X_train[i])

  plt.title(class_names[y_train[i][0]],fontsize=12)

plt.show()

# %% [markdown]
# Data Preprocessing

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

mean = np.mean(X_train)
std = np.std(X_train)

X_train = (X_train - mean)/(std + 1e-7)
X_test = (X_test - mean)/(std + 1e-7)

# %% [markdown]
# One hot encoding Labels

# %%
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

# %% [markdown]
# Data Augmentation

# %%
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,

    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,

    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,

    # Randomly flip images horizontally
    horizontal_flip=True,

    # Zoom images in by up to 10%
    zoom_range=0.1,

    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],

    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,

    # Channel shift intensity
    channel_shift_range=0.1,
)

# %%
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay),
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 32, 32, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 32, 32, 32)          │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 16, 16, 64)          │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 16, 16, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_4                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 8, 8, 128)           │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_5                │ (None, 8, 8, 128)           │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 4, 4, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 4, 4, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 4, 4, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 4, 4, 256)           │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 2, 2, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10)                  │          10,250 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
batch_size = 64

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed

# %%
model.fit(X_train, y_train, batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2,
          callbacks=[reduce_lr, early_stopping],
          verbose=2)
# Out:
# Epoch 1/300
# 625/625 - 25s - 40ms/step - accuracy: 0.3757 - loss: 2.2479 - val_accuracy: 0.4255 - val_loss: 1.7782 - learning_rate: 5.0000e-04
# Epoch 2/300
# 625/625 - 7s - 11ms/step - accuracy: 0.5331 - loss: 1.4860 - val_accuracy: 0.6083 - val_loss: 1.2710 - learning_rate: 5.0000e-04
# Epoch 3/300
# 625/625 - 6s - 10ms/step - accuracy: 0.6143 - loss: 1.2218 - val_accuracy: 0.6841 - val_loss: 1.0256 - learning_rate: 5.0000e-04
# Epoch 4/300
# 625/625 - 10s - 17ms/step - accuracy: 0.6726 - loss: 1.0426 - val_accuracy: 0.7189 - val_loss: 0.9007 - learning_rate: 5.0000e-04
# Epoch 5/300
# 625/625 - 6s - 10ms/step - accuracy: 0.7085 - loss: 0.9459 - val_accuracy: 0.7417 - val_loss: 0.8489 - learning_rate: 5.0000e-04
# Epoch 6/300
# 625/625 - 10s - 16ms/step - accuracy: 0.7368 - loss: 0.8618 - val_accuracy: 0.7685 - val_loss: 0.7890 - learning_rate: 5.0000e-04
# Epoch 7/300
# 625/625 - 6s - 10ms/step - accuracy: 0.7595 - loss: 0.8032 - val_accuracy: 0.7703 - val_loss: 0.7961 - learning_rate: 5.0000e-04
# Epoch 8/300
# 625/625 - 10s - 16ms/step - accuracy: 0.7760 - loss: 0.7639 - val_accuracy: 0.7876 - val_loss: 0.7223 - learning_rate: 5.0000e-04
# Epoch 9/300
# 625/625 - 10s - 16ms/step - accuracy: 0.7915 - loss: 0.7261 - val_accuracy: 0.7994 - val_loss: 0.7255 - learning_rate: 5.0000e-04
# Epoch 10/300
# 625/625 - 7s - 11ms/step - accuracy: 0.8045 - loss: 0.6926 - val_accuracy: 0.8104 - val_loss: 0.6897 - learning_rate: 5.0000e-04
# Epoch 11/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8174 - loss: 0.6583 - val_accuracy: 0.8052 - val_loss: 0.7081 - learning_rate: 5.0000e-04
# Epoch 12/300
# 625/625 - 7s - 11ms/step - accuracy: 0.8309 - loss: 0.6321 - val_accuracy: 0.8225 - val_loss: 0.6587 - learning_rate: 5.0000e-04
# Epoch 13/300
# Epoch 14/300
# 625/625 - 10s - 17ms/step - accuracy: 0.8487 - loss: 0.5966 - val_accuracy: 0.8266 - val_loss: 0.6784 - learning_rate: 5.0000e-04
# Epoch 15/300
# 625/625 - 10s - 16ms/step - accuracy: 0.8546 - loss: 0.5867 - val_accuracy: 0.8249 - val_loss: 0.7008 - learning_rate: 5.0000e-04
# Epoch 16/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8607 - loss: 0.5740 - val_accuracy: 0.8349 - val_loss: 0.6640 - learning_rate: 5.0000e-04
# Epoch 17/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8698 - loss: 0.5589 - val_accuracy: 0.8351 - val_loss: 0.6690 - learning_rate: 5.0000e-04
# Epoch 18/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8748 - loss: 0.5448 - val_accuracy: 0.8428 - val_loss: 0.6599 - learning_rate: 5.0000e-04
# Epoch 19/300
# 625/625 - 10s - 16ms/step - accuracy: 0.8803 - loss: 0.5345 - val_accuracy: 0.8431 - val_loss: 0.6718 - learning_rate: 5.0000e-04
# Epoch 20/300
# 625/625 - 10s - 17ms/step - accuracy: 0.8841 - loss: 0.5384 - val_accuracy: 0.8490 - val_loss: 0.6571 - learning_rate: 5.0000e-04
# Epoch 21/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8881 - loss: 0.5251 - val_accuracy: 0.8444 - val_loss: 0.6850 - learning_rate: 5.0000e-04
# Epoch 22/300
# 625/625 - 10s - 17ms/step - accuracy: 0.8931 - loss: 0.5152 - val_accuracy: 0.8450 - val_loss: 0.6840 - learning_rate: 5.0000e-04
# Epoch 23/300
# 625/625 - 6s - 10ms/step - accuracy: 0.8970 - loss: 0.5125 - val_accuracy: 0.8402 - val_loss: 0.7245 - learning_rate: 5.0000e-04
# Epoch 24/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9006 - loss: 0.5113 - val_accuracy: 0.8543 - val_loss: 0.6748 - learning_rate: 5.0000e-04
# Epoch 25/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9026 - loss: 0.5034 - val_accuracy: 0.8519 - val_loss: 0.6854 - learning_rate: 5.0000e-04
# Epoch 26/300
# 625/625 - 11s - 17ms/step - accuracy: 0.9097 - loss: 0.4908 - val_accuracy: 0.8533 - val_loss: 0.6949 - learning_rate: 5.0000e-04
# Epoch 27/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9073 - loss: 0.4984 - val_accuracy: 0.8536 - val_loss: 0.7053 - learning_rate: 5.0000e-04
# Epoch 28/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9105 - loss: 0.4952 - val_accuracy: 0.8526 - val_loss: 0.7279 - learning_rate: 5.0000e-04
# Epoch 29/300
# 625/625 - 10s - 17ms/step - accuracy: 0.9145 - loss: 0.4871 - val_accuracy: 0.8519 - val_loss: 0.7179 - learning_rate: 5.0000e-04
# Epoch 30/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9162 - loss: 0.4878 - val_accuracy: 0.8529 - val_loss: 0.7232 - learning_rate: 5.0000e-04
# Epoch 31/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9362 - loss: 0.4258 - val_accuracy: 0.8662 - val_loss: 0.6959 - learning_rate: 2.5000e-04
# Epoch 32/300
# 625/625 - 10s - 17ms/step - accuracy: 0.9445 - loss: 0.4023 - val_accuracy: 0.8650 - val_loss: 0.6956 - learning_rate: 2.5000e-04
# Epoch 33/300
# 625/625 - 11s - 17ms/step - accuracy: 0.9477 - loss: 0.3885 - val_accuracy: 0.8661 - val_loss: 0.7122 - learning_rate: 2.5000e-04
# Epoch 34/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9477 - loss: 0.3854 - val_accuracy: 0.8682 - val_loss: 0.7031 - learning_rate: 2.5000e-04
# Epoch 35/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9521 - loss: 0.3715 - val_accuracy: 0.8622 - val_loss: 0.7117 - learning_rate: 2.5000e-04
# Epoch 36/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9497 - loss: 0.3762 - val_accuracy: 0.8629 - val_loss: 0.7167 - learning_rate: 2.5000e-04
# Epoch 37/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9557 - loss: 0.3612 - val_accuracy: 0.8638 - val_loss: 0.7377 - learning_rate: 2.5000e-04
# Epoch 38/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9535 - loss: 0.3601 - val_accuracy: 0.8654 - val_loss: 0.7112 - learning_rate: 2.5000e-04
# Epoch 39/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9571 - loss: 0.3501 - val_accuracy: 0.8663 - val_loss: 0.7331 - learning_rate: 2.5000e-04
# Epoch 40/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9575 - loss: 0.3445 - val_accuracy: 0.8629 - val_loss: 0.7287 - learning_rate: 2.5000e-04
# Epoch 41/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9632 - loss: 0.3293 - val_accuracy: 0.8714 - val_loss: 0.7066 - learning_rate: 1.2500e-04
# Epoch 42/300
# 625/625 - 11s - 17ms/step - accuracy: 0.9688 - loss: 0.3088 - val_accuracy: 0.8715 - val_loss: 0.7163 - learning_rate: 1.2500e-04
# Epoch 43/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9687 - loss: 0.3056 - val_accuracy: 0.8718 - val_loss: 0.7291 - learning_rate: 1.2500e-04
# Epoch 44/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9707 - loss: 0.2998 - val_accuracy: 0.8690 - val_loss: 0.7215 - learning_rate: 1.2500e-04
# Epoch 45/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9719 - loss: 0.2940 - val_accuracy: 0.8705 - val_loss: 0.7208 - learning_rate: 1.2500e-04
# Epoch 46/300
# 625/625 - 11s - 17ms/step - accuracy: 0.9733 - loss: 0.2885 - val_accuracy: 0.8693 - val_loss: 0.7300 - learning_rate: 1.2500e-04
# Epoch 47/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9738 - loss: 0.2853 - val_accuracy: 0.8726 - val_loss: 0.7291 - learning_rate: 1.2500e-04
# Epoch 48/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9751 - loss: 0.2807 - val_accuracy: 0.8713 - val_loss: 0.7164 - learning_rate: 1.2500e-04
# Epoch 49/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9757 - loss: 0.2778 - val_accuracy: 0.8710 - val_loss: 0.7305 - learning_rate: 1.2500e-04
# Epoch 50/300
# 625/625 - 7s - 10ms/step - accuracy: 0.9743 - loss: 0.2782 - val_accuracy: 0.8742 - val_loss: 0.7241 - learning_rate: 1.2500e-04
# Epoch 51/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9787 - loss: 0.2654 - val_accuracy: 0.8755 - val_loss: 0.7109 - learning_rate: 6.2500e-05
# Epoch 52/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9787 - loss: 0.2619 - val_accuracy: 0.8753 - val_loss: 0.7154 - learning_rate: 6.2500e-05
# Epoch 53/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9800 - loss: 0.2568 - val_accuracy: 0.8754 - val_loss: 0.7227 - learning_rate: 6.2500e-05
# Epoch 54/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9821 - loss: 0.2520 - val_accuracy: 0.8768 - val_loss: 0.7293 - learning_rate: 6.2500e-05
# Epoch 55/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9808 - loss: 0.2518 - val_accuracy: 0.8755 - val_loss: 0.7232 - learning_rate: 6.2500e-05
# Epoch 56/300
# 625/625 - 7s - 11ms/step - accuracy: 0.9815 - loss: 0.2491 - val_accuracy: 0.8738 - val_loss: 0.7219 - learning_rate: 6.2500e-05
# Epoch 57/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9828 - loss: 0.2464 - val_accuracy: 0.8731 - val_loss: 0.7323 - learning_rate: 6.2500e-05
# Epoch 58/300
# 625/625 - 10s - 16ms/step - accuracy: 0.9826 - loss: 0.2459 - val_accuracy: 0.8756 - val_loss: 0.7220 - learning_rate: 6.2500e-05
# Epoch 59/300
# 625/625 - 6s - 10ms/step - accuracy: 0.9828 - loss: 0.2413 - val_accuracy: 0.8731 - val_loss: 0.7263 - learning_rate: 6.2500e-05
# Epoch 60/300
# 625/625 - 10s - 17ms/step - accuracy: 0.9829 - loss: 0.2401 - val_accuracy: 0.8745 - val_loss: 0.7310 - learning_rate: 6.2500e-05
# Epoch 60: early stopping
# Restoring model weights from the end of the best epoch: 20.

# %%
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8461 - loss: 0.6861
#
# Test Accuracy: 0.8439000248908997
# Test Loss:     0.6862329244613647

# %%
import urllib.request

# %%
url = "https://t4.ftcdn.net/jpg/00/26/80/01/360_F_26800115_YlmErNLIVZeNZXPzUc3z4GAD1gGkVABu.jpg"
resp = urllib.request.urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype="uint8")
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)

# Convert the image from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %%
image = cv2.resize(image, (32,32))

# Normalize the image
image = (image-mean)/(std+1e-7)

# Add an extra dimension because the model expects a batch of images
image = image.reshape((1, 32, 32, 3))

# %%
prediction = model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
predicted_class = prediction.argmax()

print('Predicted class: ', class_names[predicted_class])
# Out:
# Predicted class:  truck
